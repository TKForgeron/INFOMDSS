# %%
import pandas as pd
import seaborn as sns
import preprocessing_predictions as prep
import measures as m
import cases as c
import hospitalizations as h
import vaccinations as v
import temperature as t

# %%
vacc_il = v.get_vaccinations_df_il()

# %%
cases_il = c.get_cases_df_il()

# %%
sns.displot(cases_il, x="cases_per_100k")

# %%
cases_nl = c.get_cases_df_nl()

# %%
sns.displot(cases_nl, x="cases_per_100k")

# %%
cases_nsw = c.get_cases_df_nsw()

# %%
sns.displot(cases_nsw, x="cases_per_100k")
